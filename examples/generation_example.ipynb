# %%
# !pip install --quiet pymorphy2 conllu razdel sentence-transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 84.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 86.1 MB/s eta 0:00:00
#   Building wheel for docopt (setup.py) ... done

# %% [markdown]
# ## An example for generating minimal pairs using an UD Treebank
#
# Here, we show how to generate minimal pairs using an UD Treebank. The input sentences can be extracted from any text corpus and annotated by any morphosyntactic parser in the UD formatting scheme.

# %%
# %cd ../src

# %%
# !wget https://github.com/UniversalDependencies/UD_Russian-SynTagRus/raw/master/ru_syntagrus-ud-dev.conllu

# %%
phenomena = [
    "aspect",
    "tense",
    "negation",
    "reflexives",
    "government",
    "word_formation",
    "word_inflection",
    "argument_structure",
    "agreement",
]

# %%
for ph in phenomena:
    # !python generator.py --phenomenon {ph} --data_fname ru_syntagrus-ud-dev.conllu --output_fdir_name generated_data --sample True

# %% [markdown]
# ### The directory `generated_data` will contain folders with dataframes of generated minimal pairs. An example of how to load the generated pairs is the following:

# %%
ls generated_data/*/
# Out:
# generated_data/agreement/:
# ru_syntagrus-ud-dev.conllu.tsv
#
# generated_data/argument_structure/:
# ru_syntagrus-ud-dev.conllu.tsv
#
# generated_data/aspect/:
# ru_syntagrus-ud-dev.conllu.tsv
#
# generated_data/government/:
# ru_syntagrus-ud-dev.conllu.tsv
#
# generated_data/negation/:
# ru_syntagrus-ud-dev.conllu.tsv
#
# generated_data/reflexives/:
# ru_syntagrus-ud-dev.conllu.tsv
#
# generated_data/tense/:
# ru_syntagrus-ud-dev.conllu.tsv
#
# generated_data/word_formation/:
# ru_syntagrus-ud-dev.conllu.tsv
#
# generated_data/word_inflection/:
# ru_syntagrus-ud-dev.conllu.tsv

# %%
import pandas as pd


agreement = pd.read_csv(
    "generated_data/agreement/ru_syntagrus-ud-dev.conllu.tsv", sep="\t"
)
agreement.sample(5)
# Out:
#              sentence_id                                    source_sentence  \
# 808  2013Algoritm.xml_80  Новое с огромным трудом пробивало себе дорогу,...
# 666  2013Algoritm.xml_69  Английский поэт Джефри Чосер в поэме "Книга ге...
# 126  2013Algoritm.xml_11  "Алгоритм - это всякая система вычислений, вып...
# 928  2013Algoritm.xml_91  Позднее и оно, в свою очередь, подверглось иск...
# 55    2013Algoritm.xml_5  Независимые инструкции или инструкции, ставшие...
#
#                                        target_sentence  \
# 808  Новое с огромным трудом пробивал себе дорогу ,...
# 666  Английский поэт Джефри Чосер в поэме " Книга г...
# 126  " Алгоритм - это всякой система вычислений , в...
# 928  Позднее и оно , в свою очередь , подверглась и...
# 55   Независимые инструкции или инструкции , ставши...
#
#                                             annotation phenomenon  \
# 808  # sent_id = 2013Algoritm.xml_80\n# text = Ново...  agreement
# 666  # sent_id = 2013Algoritm.xml_69\n# text = Англ...  agreement
# 126  # sent_id = 2013Algoritm.xml_11\n# text = "Алг...  agreement
# 928  # sent_id = 2013Algoritm.xml_91\n# text = Позд...  agreement
# 55   # sent_id = 2013Algoritm.xml_5\n# text = Незав...  agreement
#
#                             phenomenon_subtype   source_word   target_word  \
# 808  subj_predicate_agreement_gender_attractor     пробивало      пробивал
# 666       noun_subj_predicate_agreement_person         пишет        пишешь
# 126                          np_agreement_case        всякая        всякой
# 928  subj_predicate_agreement_gender_attractor   подверглось   подверглась
# 55                           np_agreement_case  операционная  операционной
#
#                                      source_word_feats  \
# 808  {'id': 5, 'form': 'пробивало', 'lemma': 'проби...
# 666  {'id': 15, 'form': 'пишет', 'lemma': 'писать',...
# 126  {'id': 5, 'form': 'всякая', 'lemma': 'всякий',...
# 928  {'id': 9, 'form': 'подверглось', 'lemma': 'под...
# 55   {'id': 34, 'form': 'операционная', 'lemma': 'о...
#
#                                      target_word_feats feature  length  \
# 808  {'id': 5, 'form': 'пробивал', 'lemma': 'пробив...  gender      35
# 666  {'id': 15, 'form': 'пишешь', 'lemma': 'писать'...  person      39
# 126  {'id': 5, 'form': 'всякой', 'lemma': 'всякий',...    case      32
# 928  {'id': 9, 'form': 'подверглась', 'lemma': 'под...  gender      19
# 55   {'id': 34, 'form': 'операционной', 'lemma': 'о...    case      36
#
#           ipm  tree_depth
# 808  0.866667          14
# 666  0.750000          14
# 126  0.956522          11
# 928  0.928571           7
# 55   1.000000          16

# %%
agreement.phenomenon_subtype.value_counts()
# Out:
# phenomenon_subtype
# np_agreement_case                            558
# np_agreement_number                           91
# noun_subj_predicate_agreement_gender          89
# np_agreement_gender                           87
# noun_subj_predicate_agreement_person          85
# noun_subj_predicate_agreement_number          75
# subj_predicate_agreement_gender_attractor     15
# subj_predicate_agreement_number_attractor     12
# floating_quantifier_agreement_case             2
# floating_quantifier_agreement_gender           1
# Name: count, dtype: int64

# %%
negation = pd.read_csv(
    "generated_data/negation/ru_syntagrus-ud-dev.conllu.tsv", sep="\t"
)
negation
# Out:
#            sentence_id                                    source_sentence  \
# 0   2013Algoritm.xml_3  Это связано с тем, что работа каких-то инструк...
# 1  2013Algoritm.xml_11  "Алгоритм - это всякая система вычислений, вып...
# 2  2013Algoritm.xml_90  Можно обратить внимание на то, что первоначаль...
#
#                                      target_sentence  \
# 0  Это связано с тем, что работа каких-то никаких...
# 1  "Алгоритм - это всякая система вычислений, вып...
# 2  Можно обратить внимание на то, что первоначаль...
#
#                                           annotation phenomenon  \
# 0  # sent_id = 2013Algoritm.xml_3\n# text = Это с...   negation
# 1  # sent_id = 2013Algoritm.xml_11\n# text = "Алг...   negation
# 2  # sent_id = 2013Algoritm.xml_90\n# text = Можн...   negation
#
#      phenomenon_subtype  source_word target_word  \
# 0  negative_pronouns_to     каких-то     никаких
# 1  negative_pronouns_to  какого-либо    никакого
# 2  negative_pronouns_to     какое-то     никакое
#
#                                    source_word_feats  \
# 0  {'Case': 'Gen', 'Number': 'Plur', 'PronType': ...
# 1  {'Case': 'Gen', 'Gender': 'Neut', 'Number': 'S...
# 2  {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'S...
#
#                                    target_word_feats       feature  length  \
# 0  {'Case': 'Gen', 'Number': 'Plur', 'PronType': ...  pronoun_type      21
# 1  {'Case': 'Gen', 'Gender': 'Neut', 'Number': 'S...  pronoun_type      32
# 2  {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'S...  pronoun_type      28
#
#         ipm  tree_depth
# 0  1.000000           9
# 1  0.956522          11
# 2  0.920000          12

# %%
government = pd.read_csv(
    "generated_data/government/ru_syntagrus-ud-dev.conllu.tsv", sep="\t"
)
government.sample(5)
# Out:
#             sentence_id                                    source_sentence  \
# 52  2013Algoritm.xml_97  Мы видим, что понимание Эйлером алгоритма как ...
# 27  2013Algoritm.xml_54  И все они в названии имели слово algoritmi или...
# 46  2013Algoritm.xml_80  Новое с огромным трудом пробивало себе дорогу,...
# 32  2013Algoritm.xml_56  Очень распространенной была версия о греческом...
# 25  2013Algoritm.xml_43  Из оригинального названия книги происходит сло...
#
#                                       target_sentence  \
# 52  Мы видим, что понимание Эйлером алгоритма как ...
# 27  И все они в названии имели слову algoritmi или...
# 46  Новое с огромным трудом пробивало себе дороге ...
# 32  Очень распространенной была версия о греческом...
# 25  Из оригинального названия книга происходит сло...
#
#                                            annotation  phenomenon  \
# 52  # sent_id = 2013Algoritm.xml_97\n# text = Мы в...  government
# 27  # sent_id = 2013Algoritm.xml_54\n# text = И вс...  government
# 46  # sent_id = 2013Algoritm.xml_80\n# text = Ново...  government
# 32  # sent_id = 2013Algoritm.xml_56\n# text = Очен...  government
# 25  # sent_id = 2013Algoritm.xml_43\n# text = Из о...  government
#
#      phenomenon_subtype source_word target_word  \
# 52  nominalization_case      задачи      задачу
# 27      verb_acc_object       слово       слову
# 46      verb_acc_object      дорогу      дороге
# 32  nominalization_case       книги       книга
# 25  nominalization_case       книги       книга
#
#                                     source_word_feats  \
# 52  {'Animacy': 'Inan', 'Case': 'Gen', 'Gender': '...
# 27  {'Animacy': 'Inan', 'Case': 'Acc', 'Gender': '...
# 46  {'Animacy': 'Inan', 'Case': 'Acc', 'Gender': '...
# 32  {'Animacy': 'Inan', 'Case': 'Gen', 'Gender': '...
# 25  {'Animacy': 'Inan', 'Case': 'Gen', 'Gender': '...
#
#                                     target_word_feats feature  length  \
# 52  {'Animacy': 'Inan', 'Case': 'Acc', 'Gender': '...    Case      18
# 27  {'Animacy': 'Inan', 'Case': 'Dat', 'Gender': '...    Case      11
# 46  {'Animacy': 'Inan', 'Case': 'Dat', 'Gender': '...    Case      35
# 32  {'Animacy': 'Inan', 'Case': 'Nom', 'Gender': '...    Case       9
# 25  {'Animacy': 'Inan', 'Case': 'Nom', 'Gender': '...    Case      17
#
#          ipm  tree_depth
# 52  0.937500           8
# 27  0.800000           4
# 46  0.866667          14
# 32  1.000000           3
# 25  0.727273           8

# %%
government.phenomenon_subtype.value_counts()
# Out:
# phenomenon_subtype
# nominalization_case    24
# verb_acc_object        20
# adp_government_case     9
# Name: count, dtype: int64
